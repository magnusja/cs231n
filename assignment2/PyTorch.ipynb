# %% [markdown]
# # Training a ConvNet PyTorch
#
# In this notebook, you'll learn how to use the powerful PyTorch framework to specify a conv net architecture and train it on the CIFAR-10 dataset.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torch.utils.data import sampler

import torchvision.datasets as dset
import torchvision.transforms as T

import numpy as np

import timeit

# %% [markdown]
# ## What's this PyTorch business?
#
# You've written a lot of code in this assignment to provide a whole host of neural network functionality. Dropout, Batch Norm, and 2D convolutions are some of the workhorses of deep learning in computer vision. You've also worked hard to make your code efficient and vectorized.
#
# For the last part of this assignment, though, we're going to leave behind your beautiful codebase and instead migrate to one of two popular deep learning frameworks: in this instance, PyTorch (or TensorFlow, if you switch over to that notebook).
#
# Why?
#
# * Our code will now run on GPUs! Much faster training. When using a framework like PyTorch or TensorFlow you can harness the power of the GPU for your own custom neural network architectures without having to write CUDA code directly (which is beyond the scope of this class).
# * We want you to be ready to use one of these frameworks for your project so you can experiment more efficiently than if you were writing every feature you want to use by hand.
# * We want you to stand on the shoulders of giants! TensorFlow and PyTorch are both excellent frameworks that will make your lives a lot easier, and now that you understand their guts, you are free to use them :)
# * We want you to be exposed to the sort of deep learning code you might run into in academia or industry.

# %% [markdown]
# ## How will I learn PyTorch?
#
# If you've used Torch before, but are new to PyTorch, this tutorial might be of use: http://pytorch.org/tutorials/beginner/former_torchies_tutorial.html
#
# Otherwise, this notebook will walk you through much of what you need to do to train models in Torch. See the end of the notebook for some links to helpful tutorials if you want to learn more or need further clarification on topics that aren't fully explained here.

# %% [markdown]
# ## Load Datasets
#
# We load the CIFAR-10 dataset. This might take a couple minutes the first time you do it, but the files should stay cached after that.

# %%
class ChunkSampler(sampler.Sampler):
    """Samples elements sequentially from some offset. 
    Arguments:
        num_samples: # of desired datapoints
        start: offset where we should start selecting from
    """
    def __init__(self, num_samples, start = 0):
        self.num_samples = num_samples
        self.start = start

    def __iter__(self):
        return iter(range(self.start, self.start + self.num_samples))

    def __len__(self):
        return self.num_samples

NUM_TRAIN = 49000
NUM_VAL = 1000

cifar10_train = dset.CIFAR10('./cs231n/datasets', train=True, download=True,
                           transform=T.ToTensor())
loader_train = DataLoader(cifar10_train, batch_size=64, sampler=ChunkSampler(NUM_TRAIN, 0))

cifar10_val = dset.CIFAR10('./cs231n/datasets', train=True, download=True,
                           transform=T.ToTensor())
loader_val = DataLoader(cifar10_val, batch_size=64, sampler=ChunkSampler(NUM_VAL, NUM_TRAIN))

cifar10_test = dset.CIFAR10('./cs231n/datasets', train=False, download=True,
                          transform=T.ToTensor())
loader_test = DataLoader(cifar10_test, batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# For now, we're going to use a CPU-friendly datatype. Later, we'll switch to a datatype that will move all our computations to the GPU and measure the speedup.

# %%
dtype = torch.FloatTensor # the CPU datatype

# Constant to control how frequently we print train loss
print_every = 100

# This is a little utility that we'll use to reset the model
# if we want to re-initialize all our parameters
def reset(m):
    if hasattr(m, 'reset_parameters'):
        m.reset_parameters()

# %% [markdown]
# ## Example Model
#
# ### Some assorted tidbits
#
# Let's start by looking at a simple model. First, note that PyTorch operates on Tensors, which are n-dimensional arrays functionally analogous to numpy's ndarrays, with the additional feature that they can be used for computations on GPUs.
#
# We'll provide you with a Flatten function, which we explain here. Remember that our image data (and more relevantly, our intermediate feature maps) are initially N x C x H x W, where:
# * N is the number of datapoints
# * C is the number of channels
# * H is the height of the intermediate feature map in pixels
# * W is the height of the intermediate feature map in pixels
#
# This is the right way to represent the data when we are doing something like a 2D convolution, that needs spatial understanding of where the intermediate features are relative to each other. When we input  data into fully connected affine layers, however, we want each datapoint to be represented by a single vector -- it's no longer useful to segregate the different channels, rows, and columns of the data. So, we use a "Flatten" operation to collapse the C x H x W values per representation into a single long vector. The Flatten function below first reads in the N, C, H, and W values from a given batch of data, and then returns a "view" of that data. "View" is analogous to numpy's "reshape" method: it reshapes x's dimensions to be N x ??, where ?? is allowed to be anything (in this case, it will be C x H x W, but we don't need to specify that explicitly).

# %%
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size() # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

# %% [markdown]
# ### The example model itself
#
# The first step to training your own model is defining its architecture.
#
# Here's an example of a convolutional neural network defined in PyTorch -- try to understand what each line is doing, remembering that each layer is composed upon the previous layer. We haven't trained anything yet - that'll come next - for now, we want you to understand how everything gets set up.  nn.Sequential is a container which applies each layer
# one after the other.
#
# In that example, you see 2D convolutional layers (Conv2d), ReLU activations, and fully-connected layers (Linear). You also see the Cross-Entropy loss function, and the Adam optimizer being used.
#
# Make sure you understand why the parameters of the Linear layer are 5408 and 10.

# %%
# Here's where we define the architecture of the model... 
simple_model = nn.Sequential(
                nn.Conv2d(3, 32, kernel_size=7, stride=2),
                nn.ReLU(inplace=True),
                Flatten(), # see above for explanation
                nn.Linear(5408, 10), # affine layer
              )

# Set the type of all data in this model to be FloatTensor 
simple_model.type(dtype)

loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.Adam(simple_model.parameters(), lr=1e-2) # lr sets the learning rate of the optimizer

# %% [markdown]
# PyTorch supports many other layer types, loss functions, and optimizers - you will experiment with these next. Here's the official API documentation for these (if any of the parameters used above were unclear, this resource will also be helpful). One note: what we call in the class "spatial batch norm" is called "BatchNorm2D" in PyTorch.
#
# * Layers: http://pytorch.org/docs/nn.html
# * Activations: http://pytorch.org/docs/nn.html#non-linear-activations
# * Loss functions: http://pytorch.org/docs/nn.html#loss-functions
# * Optimizers: http://pytorch.org/docs/optim.html#algorithms

# %% [markdown]
# ## Training a specific model
#
# In this section, we're going to specify a model for you to construct. The goal here isn't to get good performance (that'll be next), but instead to get comfortable with understanding the PyTorch documentation and configuring your own model.
#
# Using the code provided above as guidance, and using the following PyTorch documentation, specify a model with the following architecture:
#
# * 7x7 Convolutional Layer with 32 filters and stride of 1
# * ReLU Activation Layer
# * Spatial Batch Normalization Layer
# * 2x2 Max Pooling layer with a stride of 2
# * Affine layer with 1024 output units
# * ReLU Activation Layer
# * Affine layer from 1024 input units to 10 outputs
#
# And finally, set up a **cross-entropy** loss function and the **RMSprop** learning rule.

# %%
fixed_model_base = nn.Sequential( # You fill this in!
    nn.Conv2d(3, 32, kernel_size=7, stride=1),
    nn.ReLU(inplace=True),
    nn.BatchNorm2d(32),
    nn.MaxPool2d(kernel_size=2, stride=2),
    Flatten(),
    nn.Linear(13 * 13 * 32, 1024),
    nn.ReLU(inplace=True),
    nn.Linear(1024, 10)
            )

fixed_model = fixed_model_base.type(dtype)

loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.RMSprop(simple_model.parameters(), lr=1e-2)

# %% [markdown]
# To make sure you're doing the right thing, use the following tool to check the dimensionality of your output (it should be 64 x 10, since our batches have size 64 and the output of the final affine layer should be 10, corresponding to our 10 classes):

# %%
## Now we're going to feed a random batch into the model you defined and make sure the output is the right size
x = torch.randn(64, 3, 32, 32).type(dtype)
x_var = Variable(x.type(dtype)) # Construct a PyTorch Variable out of your input data
ans = fixed_model(x_var)        # Feed it through the model! 

# Check to make sure what comes out of your model
# is the right dimensionality... this should be True
# if you've done everything correctly
np.array_equal(np.array(ans.size()), np.array([64, 10]))
# Out:
# True

# %% [markdown]
# ### GPU!
#
# Now, we're going to switch the dtype of the model and our data to the GPU-friendly tensors, and see what happens... everything is the same, except we are casting our model and input tensors as this new dtype instead of the old one.
#
# If this returns false, or otherwise fails in a not-graceful way (i.e., with some error message), you may not have an NVIDIA GPU available on your machine. If you're running locally, we recommend you switch to Google Cloud and follow the instructions to set up a GPU there. If you're already on Google Cloud, something is wrong -- make sure you followed the instructions on how to request and use a GPU on your instance. If you did, post on Piazza or come to Office Hours so we can help you debug.

# %%
# Verify that CUDA is properly configured and you have a GPU available

torch.cuda.is_available()
# Out:
# True

# %%
import copy
gpu_dtype = torch.cuda.FloatTensor

fixed_model_gpu = copy.deepcopy(fixed_model_base).type(gpu_dtype)

x_gpu = torch.randn(64, 3, 32, 32).type(gpu_dtype)
x_var_gpu = Variable(x.type(gpu_dtype)) # Construct a PyTorch Variable out of your input data
ans = fixed_model_gpu(x_var_gpu)        # Feed it through the model! 

# Check to make sure what comes out of your model
# is the right dimensionality... this should be True
# if you've done everything correctly
np.array_equal(np.array(ans.size()), np.array([64, 10]))
# Out:
# True

# %% [markdown]
# Run the following cell to evaluate the performance of the forward pass running on the CPU:

# %%
# %%timeit 
ans = fixed_model(x_var)
# Out:
# 10 loops, best of 3: 43.4 ms per loop

# %% [markdown]
# ... and now the GPU:

# %%
# %%timeit 
torch.cuda.synchronize() # Make sure there are no pending GPU computations
ans = fixed_model_gpu(x_var_gpu)        # Feed it through the model! 
torch.cuda.synchronize() # Make sure there are no pending GPU computations
# Out:
# 100 loops, best of 3: 1.88 ms per loop

# %% [markdown]
# You should observe that even a simple forward pass like this is significantly faster on the GPU. So for the rest of the assignment (and when you go train your models in assignment 3 and your project!), you should use the GPU datatype for your model and your tensors: as a reminder that is *torch.cuda.FloatTensor* (in our notebook here as *gpu_dtype*)

# %% [markdown]
# ### Train the model.
#
# Now that you've seen how to define a model and do a single forward pass of some data through it, let's  walk through how you'd actually train one whole epoch over your training data (using the simple_model we provided above).
#
# Make sure you understand how each PyTorch function used below corresponds to what you implemented in your custom neural network implementation.
#
# Note that because we are not resetting the weights anywhere below, if you run the cell multiple times, you are effectively training multiple epochs (so your performance should improve).
#
# First, set up an RMSprop optimizer (using a 1e-3 learning rate) and a cross-entropy loss function:

# %%
loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.RMSprop(simple_model.parameters(), lr=1e-3)

# %%
# This sets the model in "training" mode. This is relevant for some layers that may have different behavior
# in training mode vs testing mode, such as Dropout and BatchNorm. 
fixed_model_gpu.train()

# Load one batch at a time.
for t, (x, y) in enumerate(loader_train):
    x_var = Variable(x.type(gpu_dtype))
    y_var = Variable(y.type(gpu_dtype).long())

    # This is the forward pass: predict the scores for each class, for each x in the batch.
    scores = fixed_model_gpu(x_var)
    
    # Use the correct y values and the predicted y values to compute the loss.
    loss = loss_fn(scores, y_var)
    
    if (t + 1) % print_every == 0:
        print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

    # Zero out all of the gradients for the variables which the optimizer will update.
    optimizer.zero_grad()
    
    # This is the backwards pass: compute the gradient of the loss with respect to each 
    # parameter of the model.
    loss.backward()
    
    # Actually update the parameters of the model using the gradients computed by the backwards pass.
    optimizer.step()
# Out:
# t = 100, loss = 2.2956
# t = 200, loss = 2.3296
# t = 300, loss = 2.3038
# t = 400, loss = 2.3182
# t = 500, loss = 2.3141
# t = 600, loss = 2.2890
# t = 700, loss = 2.2939

# %% [markdown]
# Now you've seen how the training process works in PyTorch. To save you writing boilerplate code, we're providing the following helper functions to help you train for multiple epochs and check the accuracy of your model:

# %%
def train(model, loss_fn, optimizer, num_epochs = 1):
    for epoch in range(num_epochs):
        print('Starting epoch %d / %d' % (epoch + 1, num_epochs))
        model.train()
        for t, (x, y) in enumerate(loader_train):
            x_var = Variable(x.type(gpu_dtype))
            y_var = Variable(y.type(gpu_dtype).long())

            scores = model(x_var)
            
            loss = loss_fn(scores, y_var)
            if (t + 1) % print_every == 0:
                print('t = %d, loss = %.4f' % (t + 1, loss.data[0]))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

def check_accuracy(model, loader):
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')   
    num_correct = 0
    num_samples = 0
    model.eval() # Put the model in test mode (the opposite of model.train(), essentially)
    for x, y in loader:
        x_var = Variable(x.type(gpu_dtype), volatile=True)

        scores = model(x_var)
        _, preds = scores.data.cpu().max(1)
        num_correct += (preds == y).sum()
        num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
    return acc

# %% [markdown]
# ### Check the accuracy of the model.
#
# Let's see the train and check_accuracy code in action -- feel free to use these methods when evaluating the models you develop below.
#
# You should get a training loss of around 1.2-1.4, and a validation accuracy of around 50-60%. As mentioned above, if you re-run the cells, you'll be training more epochs, so your performance will improve past these numbers.
#
# But don't worry about getting these numbers better -- this was just practice before you tackle designing your own model.

# %%
torch.cuda.random.manual_seed(12345)
fixed_model_gpu.apply(reset)
train(fixed_model_gpu, loss_fn, optimizer, num_epochs=1)
check_accuracy(fixed_model_gpu, loader_val)
# Out:
# Starting epoch 1 / 1
# t = 100, loss = 2.2925
# t = 200, loss = 2.3011
# t = 300, loss = 2.3085
# t = 400, loss = 2.3127
# t = 500, loss = 2.2967
# t = 600, loss = 2.3012
# t = 700, loss = 2.3108
# Checking accuracy on validation set
# Got 81 / 1000 correct (8.10)
# 0.081

# %% [markdown]
# ### Don't forget the validation set!
#
# And note that you can use the check_accuracy function to evaluate on either the test set or the validation set, by passing either **loader_test** or **loader_val** as the second argument to check_accuracy. You should not touch the test set until you have finished your architecture and hyperparameter tuning, and only run the test set once at the end to report a final value.

# %% [markdown]
# ## Train a _great_ model on CIFAR-10!
#
# Now it's your job to experiment with architectures, hyperparameters, loss functions, and optimizers to train a model that achieves **>=70%** accuracy on the CIFAR-10 **validation** set. You can use the check_accuracy and train functions from above.

# %% [markdown]
# ### Things you should try:
# - **Filter size**: Above we used 7x7; this makes pretty pictures but smaller filters may be more efficient
# - **Number of filters**: Above we used 32 filters. Do more or fewer do better?
# - **Pooling vs Strided Convolution**: Do you use max pooling or just stride convolutions?
# - **Batch normalization**: Try adding spatial batch normalization after convolution layers and vanilla batch normalization after affine layers. Do your networks train faster?
# - **Network architecture**: The network above has two layers of trainable parameters. Can you do better with a deep network? Good architectures to try include:
#     - [conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [conv-relu-conv-relu-pool]xN -> [affine]xM -> [softmax or SVM]
#     - [batchnorm-relu-conv]xN -> [affine]xM -> [softmax or SVM]
# - **Global Average Pooling**: Instead of flattening and then having multiple affine layers, perform convolutions until your image gets small (7x7 or so) and then perform an average pooling operation to get to a 1x1 image picture (1, 1 , Filter#), which is then reshaped into a (Filter#) vector. This is used in [Google's Inception Network](https://arxiv.org/abs/1512.00567) (See Table 1 for their architecture).
# - **Regularization**: Add l2 weight regularization, or perhaps use Dropout.
#
# ### Tips for training
# For each network architecture that you try, you should tune the learning rate and regularization strength. When doing this there are a couple important things to keep in mind:
#
# - If the parameters are working well, you should see improvement within a few hundred iterations
# - Remember the coarse-to-fine approach for hyperparameter tuning: start by testing a large range of hyperparameters for just a few training iterations to find the combinations of parameters that are working at all.
# - Once you have found some sets of parameters that seem to work, search more finely around these parameters. You may need to train for more epochs.
# - You should use the validation set for hyperparameter search, and save your test set for evaluating your architecture on the best parameters as selected by the validation set.
#
# ### Going above and beyond
# If you are feeling adventurous there are many other features you can implement to try and improve your performance. You are **not required** to implement any of these; however they would be good things to try for extra credit.
#
# - Alternative update steps: For the assignment we implemented SGD+momentum, RMSprop, and Adam; you could try alternatives like AdaGrad or AdaDelta.
# - Alternative activation functions such as leaky ReLU, parametric ReLU, ELU, or MaxOut.
# - Model ensembles
# - Data augmentation
# - New Architectures
#   - [ResNets](https://arxiv.org/abs/1512.03385) where the input from the previous layer is added to the output.
#   - [DenseNets](https://arxiv.org/abs/1608.06993) where inputs into previous layers are concatenated together.
#   - [This blog has an in-depth overview](https://chatbotslife.com/resnets-highwaynets-and-densenets-oh-my-9bb15918ee32)
#
# If you do decide to implement something extra, clearly describe it in the "Extra Credit Description" cell below.
#
# ### What we expect
# At the very least, you should be able to train a ConvNet that gets at least 70% accuracy on the validation set. This is just a lower bound - if you are careful it should be possible to get accuracies much higher than that! Extra credit points will be awarded for particularly high-scoring models or unique approaches.
#
# You should use the space below to experiment and train your network.
#
# Have fun and happy training!

# %%
# Train your model here, and make sure the output of this cell is the accuracy of your best model on the 
# train, val, and test sets. Here's some code to get you started. The output of this cell should be the training
# and validation accuracy on your best model (measured by validation accuracy).

lrs = [10 ** np.random.uniform(-6, -1) for _ in range(10)]
dropouts = [np.random.uniform(0, 0.6) for _ in range(10)]
#betas = [np.random.uniform(0.95, 1) for _ in range(3)]
weight_decays = [10 ** np.random.uniform(-6, 1) for _ in range(5)]
weight_decays.append(0)
dropouts.append(0)
best_model = None
best_acc = 0

print(lrs)
print(dropouts)
print(weight_decays)

for lr in lrs:    
  for dropout in dropouts:
    #for beta1 in betas:
    #  for beta2 in betas:
    #    if abs(beta1 - beta2) < 1e-6:
    #        continue
        
    for weight_decay in weight_decays:
      with open("log.txt", "a") as myfile:
        myfile.write("Training for lr %f, dropouts %f, beta1 %f, beta2 %f, weight_decay %f\n" % (lr, dropout, 0, 0, weight_decay))
      print("Training for lr %f, dropouts %f, beta1 %f, beta2 %f, weight_decay %f" % (lr, dropout, 0, 0, weight_decay))
      model = nn.Sequential(
          nn.Conv2d(3, 96, kernel_size=3, stride=1, padding=1),
          nn.ReLU(inplace=True),
          nn.BatchNorm2d(96),
          nn.MaxPool2d(kernel_size=2, stride=2),

          nn.Conv2d(96, 256, kernel_size=3, stride=1, padding=1),
          nn.ReLU(inplace=True),
          nn.BatchNorm2d(256),
          nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
          nn.ReLU(inplace=True),
          nn.BatchNorm2d(256),
          nn.MaxPool2d(kernel_size=2, stride=2),

          nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
          nn.ReLU(inplace=True),
          nn.BatchNorm2d(512),
          nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
          nn.ReLU(inplace=True),
          nn.BatchNorm2d(512),
          nn.Dropout(p=dropout, inplace=True),
          nn.MaxPool2d(kernel_size=2, stride=2),

          nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
          nn.ReLU(inplace=True),
          nn.BatchNorm2d(512),
          nn.Dropout(p=dropout, inplace=True),
          nn.Conv2d(512, 256, kernel_size=3, stride=1, padding=1),
          nn.ReLU(inplace=True),
          nn.BatchNorm2d(256),
          nn.Dropout(p=dropout, inplace=True),
          nn.MaxPool2d(kernel_size=2, stride=2),

          Flatten(),
          nn.Linear(2 * 2 * 256, 2048),
          nn.BatchNorm1d(2048),
          nn.ReLU(inplace=True),
          nn.Dropout(p=dropout),

          nn.Linear(2048, 2048),
          nn.BatchNorm1d(2048),
          nn.ReLU(inplace=True),

          nn.Linear(2048, 10)
      )
      model.cuda()
      loss_fn = nn.CrossEntropyLoss().type(gpu_dtype)
      optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay) 

      train(model, loss_fn, optimizer, num_epochs=1)
      cur_acc = check_accuracy(model, loader_val)

      if cur_acc > best_acc:
        best_acc = cur_acc
        best_model = model


        with open("log.txt", "a") as myfile:
          myfile.write("New best model acc %f, lr %f, dropouts %f, beta1 %f, beta2 %f, weight_decay %f\n" % (cur_acc, lr, dropout, 0, 0, weight_decay))
          print("New best model acc %f, lr %f, dropouts %f, beta1 %f, beta2 %f, weight_decay %f" % (cur_acc, lr, dropout, 0, 0, weight_decay))
# Out:
# [0.0013477855030760376, 0.0007713896759373451, 7.3263321135943516e-06, 0.0026185933190916552, 0.026619029960596896, 0.047122056597572674, 0.00043095221584057167, 9.965995548339117e-05, 0.0017695633070015006, 0.0005500855324799164]
# [0.10593992746962862, 0.012146373495767082, 0.2511639784433116, 0.42260355910026853, 0.18735891369186644, 0.03624290213332373, 0.18204824098821104, 0.0009386785444503776, 0.20611613946481389, 0.45753729744619887, 0]
# [1.1862032385721444e-05, 0.0020078455556626243, 2.366130125405179, 0.0033455041089347393, 1.3555231635648457, 0]
# Training for lr 0.001348, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5569
# t = 200, loss = 1.4481
# t = 300, loss = 1.4750
# t = 400, loss = 1.0358
# t = 500, loss = 0.9927
# t = 600, loss = 1.1461
# t = 700, loss = 1.2183
# Checking accuracy on validation set
# Got 640 / 1000 correct (64.00)
# New best model acc 0.640000, lr 0.001348, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Training for lr 0.001348, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.4723
# t = 200, loss = 1.4279
# t = 300, loss = 1.4019
# t = 400, loss = 1.0733
# t = 500, loss = 1.0849
# t = 600, loss = 1.0866
# t = 700, loss = 1.4286
# Checking accuracy on validation set
# Got 585 / 1000 correct (58.50)
# Training for lr 0.001348, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.2021
# t = 200, loss = 2.2674
# t = 300, loss = 2.2064
# t = 400, loss = 2.2875
# t = 500, loss = 2.1880
# t = 600, loss = 2.2212
# t = 700, loss = 2.3247
# Checking accuracy on validation set
# Got 102 / 1000 correct (10.20)
# Training for lr 0.001348, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5785
# t = 200, loss = 1.5496
# t = 300, loss = 1.5004
# t = 400, loss = 1.2291
# t = 500, loss = 1.1796
# t = 600, loss = 1.2534
# t = 700, loss = 1.3424
# Checking accuracy on validation set
# Got 494 / 1000 correct (49.40)
# Training for lr 0.001348, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.1468
# t = 200, loss = 2.1142
# t = 300, loss = 2.1666
# t = 400, loss = 2.1503
# t = 500, loss = 2.1542
# t = 600, loss = 2.2644
# t = 700, loss = 2.1799
# Checking accuracy on validation set
# Got 147 / 1000 correct (14.70)
# Training for lr 0.001348, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5204
# t = 200, loss = 1.3994
# t = 300, loss = 1.4598
# t = 400, loss = 1.0524
# t = 500, loss = 1.0745
# t = 600, loss = 1.0826
# t = 700, loss = 1.2133
# Checking accuracy on validation set
# Got 626 / 1000 correct (62.60)
# Training for lr 0.001348, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5411
# t = 200, loss = 1.4958
# t = 300, loss = 1.4662
# t = 400, loss = 0.9949
# t = 500, loss = 1.0268
# t = 600, loss = 1.0196
# t = 700, loss = 1.1214
# Checking accuracy on validation set
# Got 617 / 1000 correct (61.70)
# Training for lr 0.001348, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.4545
# t = 200, loss = 1.4349
# t = 300, loss = 1.5045
# t = 400, loss = 1.1300
# t = 500, loss = 1.0581
# t = 600, loss = 1.1466
# t = 700, loss = 1.3752
# Checking accuracy on validation set
# Got 525 / 1000 correct (52.50)
# Training for lr 0.001348, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.0894
# t = 200, loss = 2.2129
# t = 300, loss = 2.1639
# t = 400, loss = 2.2752
# t = 500, loss = 2.2064
# t = 600, loss = 2.2333
# t = 700, loss = 2.2596
# Checking accuracy on validation set
# Got 114 / 1000 correct (11.40)
# Training for lr 0.001348, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5793
# t = 200, loss = 1.4429
# t = 300, loss = 1.3530
# t = 400, loss = 1.2304
# t = 500, loss = 1.2297
# t = 600, loss = 1.2509
# t = 700, loss = 1.3713
# Checking accuracy on validation set
# Got 553 / 1000 correct (55.30)
# Training for lr 0.001348, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.2581
# t = 200, loss = 2.1418
# t = 300, loss = 2.2114
# t = 400, loss = 2.1779
# t = 500, loss = 2.1594
# t = 600, loss = 2.1707
# t = 700, loss = 2.1921
# Checking accuracy on validation set
# Got 111 / 1000 correct (11.10)
# Training for lr 0.001348, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5528
# t = 200, loss = 1.3036
# t = 300, loss = 1.3494
# t = 400, loss = 0.8951
# t = 500, loss = 1.0656
# t = 600, loss = 1.0630
# t = 700, loss = 1.1889
# Checking accuracy on validation set
# Got 597 / 1000 correct (59.70)
# Training for lr 0.001348, dropouts 0.251164, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5336
# t = 200, loss = 1.4620
# t = 300, loss = 1.4132
# t = 400, loss = 1.0298
# t = 500, loss = 1.0309
# t = 600, loss = 0.9846
# t = 700, loss = 1.1782
# Checking accuracy on validation set
# Got 583 / 1000 correct (58.30)
# Training for lr 0.001348, dropouts 0.251164, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.5394
# t = 200, loss = 1.4962
# t = 300, loss = 1.4302
# t = 400, loss = 1.1933
# t = 500, loss = 1.1537
# t = 600, loss = 1.2245
# t = 700, loss = 1.3640
# Checking accuracy on validation set
# Got 541 / 1000 correct (54.10)
# Training for lr 0.001348, dropouts 0.251164, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.1998
# t = 200, loss = 2.2025
# t = 300, loss = 2.2016
# t = 400, loss = 2.2429
# t = 500, loss = 2.2358
# t = 600, loss = 2.2101
# t = 700, loss = 2.2612
# Checking accuracy on validation set
# Got 105 / 1000 correct (10.50)
# Training for lr 0.001348, dropouts 0.251164, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5777
# t = 200, loss = 1.4811
# t = 300, loss = 1.4186
# t = 400, loss = 1.1971
# t = 500, loss = 1.3195
# t = 600, loss = 1.1400
# t = 700, loss = 1.3688
# Checking accuracy on validation set
# Got 551 / 1000 correct (55.10)
# Training for lr 0.001348, dropouts 0.251164, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 1.9921
# t = 200, loss = 2.1360
# t = 300, loss = 2.0957
# t = 400, loss = 2.1818
# t = 500, loss = 2.1951
# t = 600, loss = 2.2123
# t = 700, loss = 2.1956
# Checking accuracy on validation set
# Got 167 / 1000 correct (16.70)
# Training for lr 0.001348, dropouts 0.251164, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.6268
# t = 200, loss = 1.3778
# t = 300, loss = 1.5262
# t = 400, loss = 0.9205
# t = 500, loss = 0.9735
# t = 600, loss = 1.0975
# t = 700, loss = 1.2574
# Checking accuracy on validation set
# Got 605 / 1000 correct (60.50)
# Training for lr 0.001348, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5458
# t = 200, loss = 1.4274
# t = 300, loss = 1.4124
# t = 400, loss = 0.8829
# t = 500, loss = 1.1335
# t = 600, loss = 1.0793
# t = 700, loss = 1.2359
# Checking accuracy on validation set
# Got 502 / 1000 correct (50.20)
# Training for lr 0.001348, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.5764
# t = 200, loss = 1.4902
# t = 300, loss = 1.5288
# t = 400, loss = 1.1292
# t = 500, loss = 1.2452
# t = 600, loss = 1.2782
# t = 700, loss = 1.3603
# Checking accuracy on validation set
# Got 440 / 1000 correct (44.00)
# Training for lr 0.001348, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.2291
# t = 200, loss = 2.1359
# t = 300, loss = 2.2567
# t = 400, loss = 2.2281
# t = 500, loss = 2.1822
# t = 600, loss = 2.2267
# t = 700, loss = 2.2312
# Checking accuracy on validation set
# Got 99 / 1000 correct (9.90)
# Training for lr 0.001348, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.6192
# t = 200, loss = 1.4462
# t = 300, loss = 1.4213
# t = 400, loss = 1.2981
# t = 500, loss = 1.2243
# t = 600, loss = 1.2480
# t = 700, loss = 1.4787
# Checking accuracy on validation set
# Got 504 / 1000 correct (50.40)
# Training for lr 0.001348, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.0922
# t = 200, loss = 2.2652
# t = 300, loss = 2.1295
# t = 400, loss = 2.2769
# t = 500, loss = 2.1983
# t = 600, loss = 2.1787
# t = 700, loss = 2.2542
# Checking accuracy on validation set
# Got 100 / 1000 correct (10.00)
# Training for lr 0.001348, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5711
# t = 200, loss = 1.5464
# t = 300, loss = 1.5108
# t = 400, loss = 0.9713
# t = 500, loss = 1.1054
# t = 600, loss = 1.2022
# t = 700, loss = 1.2240
# Checking accuracy on validation set
# Got 519 / 1000 correct (51.90)
# Training for lr 0.001348, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.4956
# t = 200, loss = 1.3635
# t = 300, loss = 1.4478
# t = 400, loss = 0.9165
# t = 500, loss = 0.9919
# t = 600, loss = 1.1071
# t = 700, loss = 1.0959
# Checking accuracy on validation set
# Got 670 / 1000 correct (67.00)
# New best model acc 0.670000, lr 0.001348, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Training for lr 0.001348, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.6353
# t = 200, loss = 1.5186
# t = 300, loss = 1.3575
# t = 400, loss = 1.0923
# t = 500, loss = 1.2089
# t = 600, loss = 1.2282
# t = 700, loss = 1.4104
# Checking accuracy on validation set
# Got 576 / 1000 correct (57.60)
# Training for lr 0.001348, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.2562
# t = 200, loss = 2.1251
# t = 300, loss = 2.2903
# t = 400, loss = 2.2398
# t = 500, loss = 2.1803
# t = 600, loss = 2.2328
# t = 700, loss = 2.2269
# Checking accuracy on validation set
# Got 97 / 1000 correct (9.70)
# Training for lr 0.001348, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5253
# t = 200, loss = 1.5559
# t = 300, loss = 1.4657
# t = 400, loss = 1.1519
# t = 500, loss = 1.2615
# t = 600, loss = 1.2226
# t = 700, loss = 1.3297
# Checking accuracy on validation set
# Got 544 / 1000 correct (54.40)
# Training for lr 0.001348, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.1430
# t = 200, loss = 2.1244
# t = 300, loss = 2.1445
# t = 400, loss = 2.1943
# t = 500, loss = 2.1477
# t = 600, loss = 2.2634
# t = 700, loss = 2.1995
# Checking accuracy on validation set
# Got 82 / 1000 correct (8.20)
# Training for lr 0.001348, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.4708
# t = 200, loss = 1.4820
# t = 300, loss = 1.3821
# t = 400, loss = 0.9086
# t = 500, loss = 0.9835
# t = 600, loss = 1.1494
# t = 700, loss = 1.2157
# Checking accuracy on validation set
# Got 637 / 1000 correct (63.70)
# Training for lr 0.001348, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.4800
# t = 200, loss = 1.4385
# t = 300, loss = 1.3489
# t = 400, loss = 0.8672
# t = 500, loss = 1.0076
# t = 600, loss = 1.0910
# t = 700, loss = 1.1964
# Checking accuracy on validation set
# Got 649 / 1000 correct (64.90)
# Training for lr 0.001348, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.5051
# t = 200, loss = 1.4782
# t = 300, loss = 1.4333
# t = 400, loss = 1.0647
# t = 500, loss = 1.2516
# t = 600, loss = 1.1126
# t = 700, loss = 1.3330
# Checking accuracy on validation set
# Got 554 / 1000 correct (55.40)
# Training for lr 0.001348, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.1364
# t = 200, loss = 2.2091
# t = 300, loss = 2.1709
# t = 400, loss = 2.2247
# t = 500, loss = 2.2058
# t = 600, loss = 2.1941
# t = 700, loss = 2.2800
# Checking accuracy on validation set
# Got 124 / 1000 correct (12.40)
# Training for lr 0.001348, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.4229
# t = 200, loss = 1.4294
# t = 300, loss = 1.3838
# t = 400, loss = 1.2225
# t = 500, loss = 1.2695
# t = 600, loss = 1.1760
# t = 700, loss = 1.2671
# Checking accuracy on validation set
# Got 537 / 1000 correct (53.70)
# Training for lr 0.001348, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.2717
# t = 200, loss = 2.1606
# t = 300, loss = 2.0836
# t = 400, loss = 2.1573
# t = 500, loss = 2.1343
# t = 600, loss = 2.1310
# t = 700, loss = 2.2452
# Checking accuracy on validation set
# Got 78 / 1000 correct (7.80)
# Training for lr 0.001348, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5720
# t = 200, loss = 1.4579
# t = 300, loss = 1.4440
# t = 400, loss = 0.9454
# t = 500, loss = 0.9827
# t = 600, loss = 1.0294
# t = 700, loss = 1.0725
# Checking accuracy on validation set
# Got 638 / 1000 correct (63.80)
# Training for lr 0.001348, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5913
# t = 200, loss = 1.3852
# t = 300, loss = 1.3924
# t = 400, loss = 0.9080
# t = 500, loss = 1.0293
# t = 600, loss = 1.0715
# t = 700, loss = 1.1190
# Checking accuracy on validation set
# Got 545 / 1000 correct (54.50)
# Training for lr 0.001348, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.6113
# t = 200, loss = 1.4142
# t = 300, loss = 1.4433
# t = 400, loss = 1.1984
# t = 500, loss = 1.2035
# t = 600, loss = 1.1508
# t = 700, loss = 1.3930
# Checking accuracy on validation set
# Got 580 / 1000 correct (58.00)
# Training for lr 0.001348, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.0691
# t = 200, loss = 2.1497
# t = 300, loss = 2.3601
# t = 400, loss = 2.2207
# t = 500, loss = 2.2184
# t = 600, loss = 2.2647
# t = 700, loss = 2.3024
# Checking accuracy on validation set
# Got 98 / 1000 correct (9.80)
# Training for lr 0.001348, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.6090
# t = 200, loss = 1.5652
# t = 300, loss = 1.4851
# t = 400, loss = 1.1381
# t = 500, loss = 1.3205
# t = 600, loss = 1.2696
# t = 700, loss = 1.3290
# Checking accuracy on validation set
# Got 531 / 1000 correct (53.10)
# Training for lr 0.001348, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.1390
# t = 200, loss = 2.2054
# t = 300, loss = 2.1351
# t = 400, loss = 2.2341
# t = 500, loss = 2.1727
# t = 600, loss = 2.1953
# t = 700, loss = 2.2207
# Checking accuracy on validation set
# Got 100 / 1000 correct (10.00)
# Training for lr 0.001348, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5105
# t = 200, loss = 1.4556
# t = 300, loss = 1.4542
# t = 400, loss = 0.9640
# t = 500, loss = 1.0301
# t = 600, loss = 1.1474
# t = 700, loss = 1.2046
# Checking accuracy on validation set
# Got 585 / 1000 correct (58.50)
# Training for lr 0.001348, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5234
# t = 200, loss = 1.4080
# t = 300, loss = 1.3950
# t = 400, loss = 0.8996
# t = 500, loss = 0.9555
# t = 600, loss = 1.0734
# t = 700, loss = 1.1138
# Checking accuracy on validation set
# Got 631 / 1000 correct (63.10)
# Training for lr 0.001348, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.6784
# t = 200, loss = 1.5745
# t = 300, loss = 1.4338
# t = 400, loss = 1.0840
# t = 500, loss = 1.1183
# t = 600, loss = 1.1416
# t = 700, loss = 1.3578
# Checking accuracy on validation set
# Got 570 / 1000 correct (57.00)
# Training for lr 0.001348, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.1581
# t = 200, loss = 2.2295
# t = 300, loss = 2.2148
# t = 400, loss = 2.2263
# t = 500, loss = 2.2114
# t = 600, loss = 2.2433
# t = 700, loss = 2.2596
# Checking accuracy on validation set
# Got 126 / 1000 correct (12.60)
# Training for lr 0.001348, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5319
# t = 200, loss = 1.5356
# t = 300, loss = 1.5148
# t = 400, loss = 1.2385
# t = 500, loss = 1.1401
# t = 600, loss = 1.2382
# t = 700, loss = 1.3875
# Checking accuracy on validation set
# Got 522 / 1000 correct (52.20)
# Training for lr 0.001348, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.0499
# t = 200, loss = 2.3373
# t = 300, loss = 2.0692
# t = 400, loss = 2.2482
# t = 500, loss = 2.1327
# t = 600, loss = 2.1579
# t = 700, loss = 2.2657
# Checking accuracy on validation set
# Got 121 / 1000 correct (12.10)
# Training for lr 0.001348, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5409
# t = 200, loss = 1.3108
# t = 300, loss = 1.2902
# t = 400, loss = 0.9092
# t = 500, loss = 1.0469
# t = 600, loss = 0.9361
# t = 700, loss = 1.0078
# Checking accuracy on validation set
# Got 620 / 1000 correct (62.00)
# Training for lr 0.001348, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.6113
# t = 200, loss = 1.4401
# t = 300, loss = 1.4758
# t = 400, loss = 0.9182
# t = 500, loss = 1.0484
# t = 600, loss = 0.8862
# t = 700, loss = 1.3175
# Checking accuracy on validation set
# Got 564 / 1000 correct (56.40)
# Training for lr 0.001348, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.5473
# t = 200, loss = 1.5024
# t = 300, loss = 1.4035
# t = 400, loss = 1.0783
# t = 500, loss = 1.2952
# t = 600, loss = 1.2276
# t = 700, loss = 1.3476
# Checking accuracy on validation set
# Got 596 / 1000 correct (59.60)
# Training for lr 0.001348, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.1443
# t = 200, loss = 2.1408
# t = 300, loss = 2.1977
# t = 400, loss = 2.2499
# t = 500, loss = 2.2442
# t = 600, loss = 2.2921
# t = 700, loss = 2.2665
# Checking accuracy on validation set
# Got 79 / 1000 correct (7.90)
# Training for lr 0.001348, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5000
# t = 200, loss = 1.5072
# t = 300, loss = 1.3564
# t = 400, loss = 1.2086
# t = 500, loss = 1.2093
# t = 600, loss = 1.2502
# t = 700, loss = 1.3442
# Checking accuracy on validation set
# Got 528 / 1000 correct (52.80)
# Training for lr 0.001348, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 1.9941
# t = 200, loss = 2.0803
# t = 300, loss = 2.1008
# t = 400, loss = 2.1914
# t = 500, loss = 2.1308
# t = 600, loss = 2.1961
# t = 700, loss = 2.2116
# Checking accuracy on validation set
# Got 112 / 1000 correct (11.20)
# Training for lr 0.001348, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.4856
# t = 200, loss = 1.4627
# t = 300, loss = 1.3844
# t = 400, loss = 0.9499
# t = 500, loss = 1.0418
# t = 600, loss = 1.0865
# t = 700, loss = 1.2300
# Checking accuracy on validation set
# Got 480 / 1000 correct (48.00)
# Training for lr 0.001348, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5948
# t = 200, loss = 1.4295
# t = 300, loss = 1.2896
# t = 400, loss = 0.9481
# t = 500, loss = 0.9613
# t = 600, loss = 1.0284
# t = 700, loss = 1.1599
# Checking accuracy on validation set
# Got 578 / 1000 correct (57.80)
# Training for lr 0.001348, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.6917
# t = 200, loss = 1.4692
# t = 300, loss = 1.5232
# t = 400, loss = 1.1929
# t = 500, loss = 1.2546
# t = 600, loss = 1.2326
# t = 700, loss = 1.4441
# Checking accuracy on validation set
# Got 494 / 1000 correct (49.40)
# Training for lr 0.001348, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.1358
# t = 200, loss = 2.1405
# t = 300, loss = 2.2791
# t = 400, loss = 2.2664
# t = 500, loss = 2.2461
# t = 600, loss = 2.2278
# t = 700, loss = 2.2513
# Checking accuracy on validation set
# Got 113 / 1000 correct (11.30)
# Training for lr 0.001348, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.6069
# t = 200, loss = 1.4743
# t = 300, loss = 1.5026
# t = 400, loss = 1.3075
# t = 500, loss = 1.2889
# t = 600, loss = 1.4218
# t = 700, loss = 1.4359
# Checking accuracy on validation set
# Got 519 / 1000 correct (51.90)
# Training for lr 0.001348, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.0106
# t = 200, loss = 2.2081
# t = 300, loss = 2.0958
# t = 400, loss = 2.2033
# t = 500, loss = 2.1355
# t = 600, loss = 2.2023
# t = 700, loss = 2.2419
# Checking accuracy on validation set
# Got 80 / 1000 correct (8.00)
# Training for lr 0.001348, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.6198
# t = 200, loss = 1.4374
# t = 300, loss = 1.5028
# t = 400, loss = 1.0095
# t = 500, loss = 1.0655
# t = 600, loss = 1.1964
# t = 700, loss = 1.2670
# Checking accuracy on validation set
# Got 520 / 1000 correct (52.00)
# Training for lr 0.001348, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.4290
# t = 200, loss = 1.4278
# t = 300, loss = 1.4425
# t = 400, loss = 0.8726
# t = 500, loss = 1.0336
# t = 600, loss = 1.0521
# t = 700, loss = 1.1658
# Checking accuracy on validation set
# Got 626 / 1000 correct (62.60)
# Training for lr 0.001348, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.6056
# t = 200, loss = 1.5893
# t = 300, loss = 1.4137
# t = 400, loss = 1.1247
# t = 500, loss = 1.1951
# t = 600, loss = 1.1788
# t = 700, loss = 1.3235
# Checking accuracy on validation set
# Got 582 / 1000 correct (58.20)
# Training for lr 0.001348, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.0403
# t = 200, loss = 2.2090
# t = 300, loss = 2.2243
# t = 400, loss = 2.2358
# t = 500, loss = 2.2683
# t = 600, loss = 2.1917
# t = 700, loss = 2.2723
# Checking accuracy on validation set
# Got 137 / 1000 correct (13.70)
# Training for lr 0.001348, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5862
# t = 200, loss = 1.6121
# t = 300, loss = 1.3522
# t = 400, loss = 1.2043
# t = 500, loss = 1.2978
# t = 600, loss = 1.2612
# t = 700, loss = 1.3540
# Checking accuracy on validation set
# Got 543 / 1000 correct (54.30)
# Training for lr 0.001348, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.3617
# t = 200, loss = 2.1671
# t = 300, loss = 2.1035
# t = 400, loss = 2.1383
# t = 500, loss = 2.1000
# t = 600, loss = 2.2041
# t = 700, loss = 2.1920
# Checking accuracy on validation set
# Got 102 / 1000 correct (10.20)
# Training for lr 0.001348, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5163
# t = 200, loss = 1.3477
# t = 300, loss = 1.3821
# t = 400, loss = 0.8859
# t = 500, loss = 0.9406
# t = 600, loss = 1.0772
# t = 700, loss = 1.1845
# Checking accuracy on validation set
# Got 618 / 1000 correct (61.80)
# Training for lr 0.000771, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.4968
# t = 200, loss = 1.4424
# t = 300, loss = 1.2922
# t = 400, loss = 0.7949
# t = 500, loss = 1.0196
# t = 600, loss = 0.9850
# t = 700, loss = 1.0882
# Checking accuracy on validation set
# Got 685 / 1000 correct (68.50)
# New best model acc 0.685000, lr 0.000771, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Training for lr 0.000771, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.5159
# t = 200, loss = 1.4609
# t = 300, loss = 1.3339
# t = 400, loss = 1.0692
# t = 500, loss = 1.0972
# t = 600, loss = 1.0388
# t = 700, loss = 1.1893
# Checking accuracy on validation set
# Got 598 / 1000 correct (59.80)
# Training for lr 0.000771, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.2156
# t = 200, loss = 2.0859
# t = 300, loss = 2.1434
# t = 400, loss = 2.1692
# t = 500, loss = 2.1727
# t = 600, loss = 2.1693
# t = 700, loss = 2.1596
# Checking accuracy on validation set
# Got 99 / 1000 correct (9.90)
# Training for lr 0.000771, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5045
# t = 200, loss = 1.3539
# t = 300, loss = 1.3188
# t = 400, loss = 0.9792
# t = 500, loss = 1.0383
# t = 600, loss = 1.1426
# t = 700, loss = 1.2330
# Checking accuracy on validation set
# Got 629 / 1000 correct (62.90)
# Training for lr 0.000771, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 1.8933
# t = 200, loss = 2.0195
# t = 300, loss = 2.1485
# t = 400, loss = 2.0028
# t = 500, loss = 2.0546
# t = 600, loss = 2.0171
# t = 700, loss = 2.2098
# Checking accuracy on validation set
# Got 207 / 1000 correct (20.70)
# Training for lr 0.000771, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5112
# t = 200, loss = 1.4067
# t = 300, loss = 1.3604
# t = 400, loss = 0.9171
# t = 500, loss = 1.0484
# t = 600, loss = 1.0079
# t = 700, loss = 1.0847
# Checking accuracy on validation set
# Got 651 / 1000 correct (65.10)
# Training for lr 0.000771, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5226
# t = 200, loss = 1.3629
# t = 300, loss = 1.2764
# t = 400, loss = 0.7725
# t = 500, loss = 0.8314
# t = 600, loss = 1.0129
# t = 700, loss = 0.9730
# Checking accuracy on validation set
# Got 677 / 1000 correct (67.70)
# Training for lr 0.000771, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.4427
# t = 200, loss = 1.3586
# t = 300, loss = 1.2523
# t = 400, loss = 0.8476
# t = 500, loss = 1.0231
# t = 600, loss = 1.0034
# t = 700, loss = 1.0874
# Checking accuracy on validation set
# Got 670 / 1000 correct (67.00)
# Training for lr 0.000771, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.1020
# t = 200, loss = 2.0638
# t = 300, loss = 2.0726
# t = 400, loss = 2.0930
# t = 500, loss = 2.1177
# t = 600, loss = 2.1070
# t = 700, loss = 2.1366
# Checking accuracy on validation set
# Got 156 / 1000 correct (15.60)
# Training for lr 0.000771, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5158
# t = 200, loss = 1.3563
# t = 300, loss = 1.2707
# t = 400, loss = 1.0265
# t = 500, loss = 1.0504
# t = 600, loss = 1.1661
# t = 700, loss = 1.2552
# Checking accuracy on validation set
# Got 631 / 1000 correct (63.10)
# Training for lr 0.000771, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.0692
# t = 200, loss = 2.0115
# t = 300, loss = 2.0534
# t = 400, loss = 2.0504
# t = 500, loss = 2.0855
# t = 600, loss = 2.0740
# t = 700, loss = 2.0967
# Checking accuracy on validation set
# Got 115 / 1000 correct (11.50)
# Training for lr 0.000771, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5209
# t = 200, loss = 1.3931
# t = 300, loss = 1.3622
# t = 400, loss = 0.8119
# t = 500, loss = 1.0080
# t = 600, loss = 1.0885
# t = 700, loss = 0.9993
# Checking accuracy on validation set
# Got 659 / 1000 correct (65.90)
# Training for lr 0.000771, dropouts 0.251164, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5332
# t = 200, loss = 1.2967
# t = 300, loss = 1.3238
# t = 400, loss = 0.8725
# t = 500, loss = 0.9511
# t = 600, loss = 1.0124
# t = 700, loss = 1.1359
# Checking accuracy on validation set
# Got 656 / 1000 correct (65.60)
# Training for lr 0.000771, dropouts 0.251164, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.5670
# t = 200, loss = 1.4753
# t = 300, loss = 1.3881
# t = 400, loss = 0.9200
# t = 500, loss = 1.1313
# t = 600, loss = 1.0039
# t = 700, loss = 1.2283
# Checking accuracy on validation set
# Got 646 / 1000 correct (64.60)
# Training for lr 0.000771, dropouts 0.251164, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.0623
# t = 200, loss = 1.9751
# t = 300, loss = 2.0445
# t = 400, loss = 2.1995
# t = 500, loss = 2.1117
# t = 600, loss = 2.1326
# t = 700, loss = 2.0761
# Checking accuracy on validation set
# Got 80 / 1000 correct (8.00)
# Training for lr 0.000771, dropouts 0.251164, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.4966
# t = 200, loss = 1.4418
# t = 300, loss = 1.4222
# t = 400, loss = 0.9735
# t = 500, loss = 1.1264
# t = 600, loss = 1.0237
# t = 700, loss = 1.2068
# Checking accuracy on validation set
# Got 592 / 1000 correct (59.20)
# Training for lr 0.000771, dropouts 0.251164, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.0254
# t = 200, loss = 2.0379
# t = 300, loss = 2.0857
# t = 400, loss = 2.0707
# t = 500, loss = 2.0967
# t = 600, loss = 2.0662
# t = 700, loss = 2.1338
# Checking accuracy on validation set
# Got 151 / 1000 correct (15.10)
# Training for lr 0.000771, dropouts 0.251164, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5560
# t = 200, loss = 1.3876
# t = 300, loss = 1.3319
# t = 400, loss = 0.9107
# t = 500, loss = 1.0376
# t = 600, loss = 0.9595
# t = 700, loss = 1.1140
# Checking accuracy on validation set
# Got 641 / 1000 correct (64.10)
# Training for lr 0.000771, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5732
# t = 200, loss = 1.4484
# t = 300, loss = 1.4247
# t = 400, loss = 0.9007
# t = 500, loss = 0.9836
# t = 600, loss = 1.0918
# t = 700, loss = 1.1633
# Checking accuracy on validation set
# Got 597 / 1000 correct (59.70)
# Training for lr 0.000771, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.5651
# t = 200, loss = 1.3100
# t = 300, loss = 1.3970
# t = 400, loss = 1.0019
# t = 500, loss = 1.0823
# t = 600, loss = 1.1606
# t = 700, loss = 1.2042
# Checking accuracy on validation set
# Got 539 / 1000 correct (53.90)
# Training for lr 0.000771, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.1362
# t = 200, loss = 2.0022
# t = 300, loss = 2.0243
# t = 400, loss = 2.1297
# t = 500, loss = 2.1010
# t = 600, loss = 2.1205
# t = 700, loss = 2.1524
# Checking accuracy on validation set
# Got 173 / 1000 correct (17.30)
# Training for lr 0.000771, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5342
# t = 200, loss = 1.3970
# t = 300, loss = 1.3667
# t = 400, loss = 1.0890
# t = 500, loss = 1.2003
# t = 600, loss = 1.1922
# t = 700, loss = 1.2982
# Checking accuracy on validation set
# Got 583 / 1000 correct (58.30)
# Training for lr 0.000771, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 1.9481
# t = 200, loss = 2.0400
# t = 300, loss = 2.0720
# t = 400, loss = 2.0704
# t = 500, loss = 2.0912
# t = 600, loss = 2.0568
# t = 700, loss = 2.0219
# Checking accuracy on validation set
# Got 161 / 1000 correct (16.10)
# Training for lr 0.000771, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.6446
# t = 200, loss = 1.4961
# t = 300, loss = 1.3463
# t = 400, loss = 0.8950
# t = 500, loss = 0.9125
# t = 600, loss = 0.9084
# t = 700, loss = 1.0496
# Checking accuracy on validation set
# Got 566 / 1000 correct (56.60)
# Training for lr 0.000771, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5343
# t = 200, loss = 1.3330
# t = 300, loss = 1.2648
# t = 400, loss = 0.8118
# t = 500, loss = 0.9662
# t = 600, loss = 1.0005
# t = 700, loss = 1.0772
# Checking accuracy on validation set
# Got 648 / 1000 correct (64.80)
# Training for lr 0.000771, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.3631
# t = 200, loss = 1.3972
# t = 300, loss = 1.4104
# t = 400, loss = 0.8955
# t = 500, loss = 0.9754
# t = 600, loss = 1.0493
# t = 700, loss = 1.2477
# Checking accuracy on validation set
# Got 621 / 1000 correct (62.10)
# Training for lr 0.000771, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 1.9728
# t = 200, loss = 2.0400
# t = 300, loss = 2.0765
# t = 400, loss = 2.1303
# t = 500, loss = 2.0785
# t = 600, loss = 2.1007
# t = 700, loss = 2.1100
# Checking accuracy on validation set
# Got 79 / 1000 correct (7.90)
# Training for lr 0.000771, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.4430
# t = 200, loss = 1.4348
# t = 300, loss = 1.3102
# t = 400, loss = 1.0415
# t = 500, loss = 1.0297
# t = 600, loss = 1.0448
# t = 700, loss = 1.3082
# Checking accuracy on validation set
# Got 629 / 1000 correct (62.90)
# Training for lr 0.000771, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 1.9637
# t = 200, loss = 2.0572
# t = 300, loss = 2.0254
# t = 400, loss = 2.0278
# t = 500, loss = 2.0279
# t = 600, loss = 2.0993
# t = 700, loss = 2.0589
# Checking accuracy on validation set
# Got 146 / 1000 correct (14.60)
# Training for lr 0.000771, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5335
# t = 200, loss = 1.3972
# t = 300, loss = 1.2882
# t = 400, loss = 0.9988
# t = 500, loss = 1.0508
# t = 600, loss = 1.0682
# t = 700, loss = 1.1186
# Checking accuracy on validation set
# Got 637 / 1000 correct (63.70)
# Training for lr 0.000771, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5185
# t = 200, loss = 1.3864
# t = 300, loss = 1.3037
# t = 400, loss = 0.8586
# t = 500, loss = 1.0402
# t = 600, loss = 1.0176
# t = 700, loss = 1.1283
# Checking accuracy on validation set
# Got 692 / 1000 correct (69.20)
# New best model acc 0.692000, lr 0.000771, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Training for lr 0.000771, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.4624
# t = 200, loss = 1.3866
# t = 300, loss = 1.2889
# t = 400, loss = 1.0271
# t = 500, loss = 1.0400
# t = 600, loss = 1.0904
# t = 700, loss = 1.2533
# Checking accuracy on validation set
# Got 632 / 1000 correct (63.20)
# Training for lr 0.000771, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.0792
# t = 200, loss = 2.1941
# t = 300, loss = 2.1202
# t = 400, loss = 2.1387
# t = 500, loss = 2.1218
# t = 600, loss = 2.2243
# t = 700, loss = 2.1823
# Checking accuracy on validation set
# Got 128 / 1000 correct (12.80)
# Training for lr 0.000771, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5696
# t = 200, loss = 1.3933
# t = 300, loss = 1.3109
# t = 400, loss = 0.9757
# t = 500, loss = 1.1165
# t = 600, loss = 1.2226
# t = 700, loss = 1.2350
# Checking accuracy on validation set
# Got 603 / 1000 correct (60.30)
# Training for lr 0.000771, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.0418
# t = 200, loss = 2.1290
# t = 300, loss = 1.9834
# t = 400, loss = 2.0522
# t = 500, loss = 2.1186
# t = 600, loss = 2.0627
# t = 700, loss = 2.0967
# Checking accuracy on validation set
# Got 197 / 1000 correct (19.70)
# Training for lr 0.000771, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5483
# t = 200, loss = 1.2991
# t = 300, loss = 1.2600
# t = 400, loss = 0.7351
# t = 500, loss = 0.8562
# t = 600, loss = 1.0170
# t = 700, loss = 1.0844
# Checking accuracy on validation set
# Got 693 / 1000 correct (69.30)
# New best model acc 0.693000, lr 0.000771, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Training for lr 0.000771, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5491
# t = 200, loss = 1.3618
# t = 300, loss = 1.2633
# t = 400, loss = 0.9039
# t = 500, loss = 1.0338
# t = 600, loss = 1.1011
# t = 700, loss = 1.1485
# Checking accuracy on validation set
# Got 628 / 1000 correct (62.80)
# Training for lr 0.000771, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.4651
# t = 200, loss = 1.4267
# t = 300, loss = 1.4433
# t = 400, loss = 0.9920
# t = 500, loss = 1.0976
# t = 600, loss = 1.0374
# t = 700, loss = 1.2019
# Checking accuracy on validation set
# Got 640 / 1000 correct (64.00)
# Training for lr 0.000771, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.0330
# t = 200, loss = 2.0579
# t = 300, loss = 2.0913
# t = 400, loss = 2.1127
# t = 500, loss = 2.1680
# t = 600, loss = 2.1218
# t = 700, loss = 2.1802
# Checking accuracy on validation set
# Got 85 / 1000 correct (8.50)
# Training for lr 0.000771, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5272
# t = 200, loss = 1.3329
# t = 300, loss = 1.3096
# t = 400, loss = 0.9317
# t = 500, loss = 1.0543
# t = 600, loss = 1.0929
# t = 700, loss = 1.1101
# Checking accuracy on validation set
# Got 627 / 1000 correct (62.70)
# Training for lr 0.000771, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.0193
# t = 200, loss = 1.9982
# t = 300, loss = 2.0884
# t = 400, loss = 2.0265
# t = 500, loss = 2.0171
# t = 600, loss = 2.1096
# t = 700, loss = 2.1389
# Checking accuracy on validation set
# Got 102 / 1000 correct (10.20)
# Training for lr 0.000771, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.6172
# t = 200, loss = 1.3947
# t = 300, loss = 1.3395
# t = 400, loss = 0.8514
# t = 500, loss = 0.9333
# t = 600, loss = 0.9627
# t = 700, loss = 1.0681
# Checking accuracy on validation set
# Got 629 / 1000 correct (62.90)
# Training for lr 0.000771, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.4397
# t = 200, loss = 1.3824
# t = 300, loss = 1.2757
# t = 400, loss = 0.8315
# t = 500, loss = 0.9647
# t = 600, loss = 1.1138
# t = 700, loss = 1.1257
# Checking accuracy on validation set
# Got 666 / 1000 correct (66.60)
# Training for lr 0.000771, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.4134
# t = 200, loss = 1.3712
# t = 300, loss = 1.3429
# t = 400, loss = 0.9448
# t = 500, loss = 0.9880
# t = 600, loss = 0.9406
# t = 700, loss = 1.1549
# Checking accuracy on validation set
# Got 623 / 1000 correct (62.30)
# Training for lr 0.000771, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.0053
# t = 200, loss = 2.1446
# t = 300, loss = 2.1358
# t = 400, loss = 2.1697
# t = 500, loss = 2.1378
# t = 600, loss = 2.2075
# t = 700, loss = 2.1637
# Checking accuracy on validation set
# Got 119 / 1000 correct (11.90)
# Training for lr 0.000771, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5218
# t = 200, loss = 1.3580
# t = 300, loss = 1.2771
# t = 400, loss = 0.9080
# t = 500, loss = 1.1116
# t = 600, loss = 1.1301
# t = 700, loss = 1.1436
# Checking accuracy on validation set
# Got 628 / 1000 correct (62.80)
# Training for lr 0.000771, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.1393
# t = 200, loss = 2.0724
# t = 300, loss = 2.0583
# t = 400, loss = 2.0381
# t = 500, loss = 2.1044
# t = 600, loss = 2.0712
# t = 700, loss = 2.0725
# Checking accuracy on validation set
# Got 100 / 1000 correct (10.00)
# Training for lr 0.000771, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.4631
# t = 200, loss = 1.2944
# t = 300, loss = 1.3956
# t = 400, loss = 0.8914
# t = 500, loss = 1.0517
# t = 600, loss = 0.9835
# t = 700, loss = 1.0249
# Checking accuracy on validation set
# Got 630 / 1000 correct (63.00)
# Training for lr 0.000771, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.4155
# t = 200, loss = 1.3634
# t = 300, loss = 1.3566
# t = 400, loss = 0.8652
# t = 500, loss = 0.9771
# t = 600, loss = 1.0897
# t = 700, loss = 1.1003
# Checking accuracy on validation set
# Got 659 / 1000 correct (65.90)
# Training for lr 0.000771, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.4412
# t = 200, loss = 1.3605
# t = 300, loss = 1.2894
# t = 400, loss = 0.9481
# t = 500, loss = 1.1067
# t = 600, loss = 1.0387
# t = 700, loss = 1.1533
# Checking accuracy on validation set
# Got 630 / 1000 correct (63.00)
# Training for lr 0.000771, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.0519
# t = 200, loss = 2.1063
# t = 300, loss = 2.0738
# t = 400, loss = 2.1369
# t = 500, loss = 2.0921
# t = 600, loss = 2.1375
# t = 700, loss = 2.1171
# Checking accuracy on validation set
# Got 97 / 1000 correct (9.70)
# Training for lr 0.000771, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.4166
# t = 200, loss = 1.4021
# t = 300, loss = 1.4198
# t = 400, loss = 1.0724
# t = 500, loss = 1.0719
# t = 600, loss = 1.0363
# t = 700, loss = 1.3121
# Checking accuracy on validation set
# Got 590 / 1000 correct (59.00)
# Training for lr 0.000771, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 1.9715
# t = 200, loss = 1.9902
# t = 300, loss = 2.1088
# t = 400, loss = 2.0673
# t = 500, loss = 2.1135
# t = 600, loss = 2.1279
# t = 700, loss = 2.1700
# Checking accuracy on validation set
# Got 177 / 1000 correct (17.70)
# Training for lr 0.000771, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.4969
# t = 200, loss = 1.2937
# t = 300, loss = 1.2640
# t = 400, loss = 0.8723
# t = 500, loss = 0.9325
# t = 600, loss = 0.9456
# t = 700, loss = 1.2312
# Checking accuracy on validation set
# Got 687 / 1000 correct (68.70)
# Training for lr 0.000771, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5012
# t = 200, loss = 1.4410
# t = 300, loss = 1.3054
# t = 400, loss = 0.9033
# t = 500, loss = 1.0380
# t = 600, loss = 0.9878
# t = 700, loss = 1.1787
# Checking accuracy on validation set
# Got 577 / 1000 correct (57.70)
# Training for lr 0.000771, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.5335
# t = 200, loss = 1.4030
# t = 300, loss = 1.4667
# t = 400, loss = 0.9640
# t = 500, loss = 1.0373
# t = 600, loss = 1.1153
# t = 700, loss = 1.2397
# Checking accuracy on validation set
# Got 529 / 1000 correct (52.90)
# Training for lr 0.000771, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.0371
# t = 200, loss = 2.1015
# t = 300, loss = 2.0615
# t = 400, loss = 2.1955
# t = 500, loss = 2.1521
# t = 600, loss = 2.2131
# t = 700, loss = 2.1077
# Checking accuracy on validation set
# Got 111 / 1000 correct (11.10)
# Training for lr 0.000771, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.6782
# t = 200, loss = 1.4928
# t = 300, loss = 1.3624
# t = 400, loss = 1.0732
# t = 500, loss = 1.1703
# t = 600, loss = 1.1428
# t = 700, loss = 1.3468
# Checking accuracy on validation set
# Got 545 / 1000 correct (54.50)
# Training for lr 0.000771, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.0331
# t = 200, loss = 1.9198
# t = 300, loss = 2.0108
# t = 400, loss = 2.0564
# t = 500, loss = 2.0250
# t = 600, loss = 2.0578
# t = 700, loss = 2.1177
# Checking accuracy on validation set
# Got 168 / 1000 correct (16.80)
# Training for lr 0.000771, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.5588
# t = 200, loss = 1.5421
# t = 300, loss = 1.3032
# t = 400, loss = 0.9078
# t = 500, loss = 0.9374
# t = 600, loss = 1.0878
# t = 700, loss = 1.1227
# Checking accuracy on validation set
# Got 551 / 1000 correct (55.10)
# Training for lr 0.000771, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.4908
# t = 200, loss = 1.3484
# t = 300, loss = 1.2656
# t = 400, loss = 0.8546
# t = 500, loss = 1.0166
# t = 600, loss = 0.9496
# t = 700, loss = 0.9730
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
# New best model acc 0.703000, lr 0.000771, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Training for lr 0.000771, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.5335
# t = 200, loss = 1.3790
# t = 300, loss = 1.4949
# t = 400, loss = 0.9398
# t = 500, loss = 1.0998
# t = 600, loss = 1.3045
# t = 700, loss = 1.0923
# Checking accuracy on validation set
# Got 634 / 1000 correct (63.40)
# Training for lr 0.000771, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.2371
# t = 200, loss = 2.1465
# t = 300, loss = 2.0647
# t = 400, loss = 2.1762
# t = 500, loss = 2.0996
# t = 600, loss = 2.1243
# t = 700, loss = 2.1503
# Checking accuracy on validation set
# Got 90 / 1000 correct (9.00)
# Training for lr 0.000771, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5124
# t = 200, loss = 1.3266
# t = 300, loss = 1.3520
# t = 400, loss = 0.9708
# t = 500, loss = 1.1184
# t = 600, loss = 1.1882
# t = 700, loss = 1.2274
# Checking accuracy on validation set
# Got 633 / 1000 correct (63.30)
# Training for lr 0.000771, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 1.9459
# t = 200, loss = 2.0827
# t = 300, loss = 2.0742
# t = 400, loss = 2.1504
# t = 500, loss = 2.1813
# t = 600, loss = 2.0758
# t = 700, loss = 2.0440
# Checking accuracy on validation set
# Got 89 / 1000 correct (8.90)
# Training for lr 0.000771, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.4665
# t = 200, loss = 1.3568
# t = 300, loss = 1.3299
# t = 400, loss = 0.8109
# t = 500, loss = 1.0039
# t = 600, loss = 1.0825
# t = 700, loss = 1.0571
# Checking accuracy on validation set
# Got 666 / 1000 correct (66.60)
# Training for lr 0.000007, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.9509
# t = 200, loss = 1.7923
# t = 300, loss = 1.7021
# t = 400, loss = 1.6060
# t = 500, loss = 1.4010
# t = 600, loss = 1.5413
# t = 700, loss = 1.5471
# Checking accuracy on validation set
# Got 530 / 1000 correct (53.00)
# Training for lr 0.000007, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.9811
# t = 200, loss = 1.8300
# t = 300, loss = 1.7975
# t = 400, loss = 1.5312
# t = 500, loss = 1.4997
# t = 600, loss = 1.5032
# t = 700, loss = 1.6331
# Checking accuracy on validation set
# Got 503 / 1000 correct (50.30)
# Training for lr 0.000007, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.2677
# ...
# t = 200, loss = 2.2828
# t = 300, loss = 2.3291
# t = 400, loss = 2.2465
# t = 500, loss = 2.1837
# t = 600, loss = 2.1943
# t = 700, loss = 2.1620
# Checking accuracy on validation set
# Got 271 / 1000 correct (27.10)
# Training for lr 0.000007, dropouts 0.422604, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 2.2577
# t = 200, loss = 2.1152
# t = 300, loss = 2.0947
# t = 400, loss = 2.0604
# t = 500, loss = 1.9109
# t = 600, loss = 1.8218
# t = 700, loss = 1.8702
# Checking accuracy on validation set
# Got 295 / 1000 correct (29.50)
# Training for lr 0.000007, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 2.0986
# t = 200, loss = 1.9229
# t = 300, loss = 1.8545
# t = 400, loss = 1.6752
# t = 500, loss = 1.5856
# t = 600, loss = 1.5799
# t = 700, loss = 1.5949
# Checking accuracy on validation set
# Got 476 / 1000 correct (47.60)
# Training for lr 0.000007, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 2.1077
# t = 200, loss = 1.9613
# t = 300, loss = 1.8928
# t = 400, loss = 1.6676
# t = 500, loss = 1.5330
# t = 600, loss = 1.5460
# t = 700, loss = 1.6116
# Checking accuracy on validation set
# Got 491 / 1000 correct (49.10)
# Training for lr 0.000007, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.2291
# t = 200, loss = 2.2432
# t = 300, loss = 2.2321
# t = 400, loss = 2.2059
# t = 500, loss = 2.1616
# t = 600, loss = 2.1186
# t = 700, loss = 2.0742
# Checking accuracy on validation set
# Got 324 / 1000 correct (32.40)
# Training for lr 0.000007, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 2.1282
# t = 200, loss = 1.9216
# t = 300, loss = 1.9030
# t = 400, loss = 1.6892
# t = 500, loss = 1.6154
# t = 600, loss = 1.5428
# t = 700, loss = 1.6604
# Checking accuracy on validation set
# Got 508 / 1000 correct (50.80)
# Training for lr 0.000007, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.2913
# t = 200, loss = 2.2352
# t = 300, loss = 2.1733
# t = 400, loss = 2.1533
# t = 500, loss = 2.0352
# t = 600, loss = 2.0262
# t = 700, loss = 1.9226
# Checking accuracy on validation set
# Got 389 / 1000 correct (38.90)
# Training for lr 0.000007, dropouts 0.187359, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 2.1327
# t = 200, loss = 1.8858
# t = 300, loss = 1.7988
# t = 400, loss = 1.6324
# t = 500, loss = 1.4762
# t = 600, loss = 1.5798
# t = 700, loss = 1.6306
# Checking accuracy on validation set
# Got 508 / 1000 correct (50.80)
# Training for lr 0.000007, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.9349
# t = 200, loss = 1.7655
# t = 300, loss = 1.7028
# t = 400, loss = 1.4814
# t = 500, loss = 1.3553
# t = 600, loss = 1.5062
# t = 700, loss = 1.5487
# Checking accuracy on validation set
# Got 554 / 1000 correct (55.40)
# Training for lr 0.000007, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 2.0076
# t = 200, loss = 1.8382
# t = 300, loss = 1.7658
# t = 400, loss = 1.5245
# t = 500, loss = 1.4439
# t = 600, loss = 1.4799
# t = 700, loss = 1.5273
# Checking accuracy on validation set
# Got 540 / 1000 correct (54.00)
# Training for lr 0.000007, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.2843
# t = 200, loss = 2.2007
# t = 300, loss = 2.1510
# t = 400, loss = 2.1233
# t = 500, loss = 2.0030
# t = 600, loss = 2.0178
# t = 700, loss = 1.9929
# Checking accuracy on validation set
# Got 403 / 1000 correct (40.30)
# Training for lr 0.000007, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 2.0594
# t = 200, loss = 1.8098
# t = 300, loss = 1.7550
# t = 400, loss = 1.5128
# t = 500, loss = 1.4254
# t = 600, loss = 1.4884
# t = 700, loss = 1.5128
# Checking accuracy on validation set
# Got 535 / 1000 correct (53.50)
# Training for lr 0.000007, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.2046
# t = 200, loss = 2.1222
# t = 300, loss = 2.0393
# t = 400, loss = 1.9885
# t = 500, loss = 1.8310
# t = 600, loss = 1.8899
# t = 700, loss = 1.8624
# Checking accuracy on validation set
# Got 430 / 1000 correct (43.00)
# Training for lr 0.000007, dropouts 0.036243, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 2.0227
# t = 200, loss = 1.7733
# t = 300, loss = 1.6733
# t = 400, loss = 1.4631
# t = 500, loss = 1.3770
# t = 600, loss = 1.4275
# t = 700, loss = 1.5383
# Checking accuracy on validation set
# Got 549 / 1000 correct (54.90)
# Training for lr 0.000007, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 2.0940
# t = 200, loss = 1.9004
# t = 300, loss = 1.8375
# t = 400, loss = 1.6508
# t = 500, loss = 1.5773
# t = 600, loss = 1.5583
# t = 700, loss = 1.6302
# Checking accuracy on validation set
# Got 496 / 1000 correct (49.60)
# Training for lr 0.000007, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 2.1118
# t = 200, loss = 1.8808
# t = 300, loss = 1.8506
# t = 400, loss = 1.7230
# t = 500, loss = 1.5745
# t = 600, loss = 1.5259
# t = 700, loss = 1.5854
# Checking accuracy on validation set
# Got 506 / 1000 correct (50.60)
# Training for lr 0.000007, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.2970
# t = 200, loss = 2.2466
# t = 300, loss = 2.2142
# t = 400, loss = 2.2006
# t = 500, loss = 2.1241
# t = 600, loss = 2.1153
# t = 700, loss = 2.0642
# Checking accuracy on validation set
# Got 366 / 1000 correct (36.60)
# Training for lr 0.000007, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 2.1003
# t = 200, loss = 1.9311
# t = 300, loss = 1.8538
# t = 400, loss = 1.7295
# t = 500, loss = 1.5785
# t = 600, loss = 1.6071
# t = 700, loss = 1.6224
# Checking accuracy on validation set
# Got 483 / 1000 correct (48.30)
# Training for lr 0.000007, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.2908
# t = 200, loss = 2.2051
# t = 300, loss = 2.2117
# t = 400, loss = 2.1141
# t = 500, loss = 1.9867
# t = 600, loss = 2.0053
# t = 700, loss = 1.9530
# Checking accuracy on validation set
# Got 377 / 1000 correct (37.70)
# Training for lr 0.000007, dropouts 0.182048, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 2.1117
# t = 200, loss = 1.9533
# t = 300, loss = 1.8379
# t = 400, loss = 1.6863
# t = 500, loss = 1.5865
# t = 600, loss = 1.6119
# t = 700, loss = 1.6742
# Checking accuracy on validation set
# Got 499 / 1000 correct (49.90)
# Training for lr 0.000007, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.9257
# t = 200, loss = 1.7688
# t = 300, loss = 1.6454
# t = 400, loss = 1.4202
# t = 500, loss = 1.3313
# t = 600, loss = 1.4370
# t = 700, loss = 1.5583
# Checking accuracy on validation set
# Got 556 / 1000 correct (55.60)
# Training for lr 0.000007, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.8977
# t = 200, loss = 1.7105
# t = 300, loss = 1.6533
# t = 400, loss = 1.4330
# t = 500, loss = 1.3171
# t = 600, loss = 1.4389
# t = 700, loss = 1.4709
# Checking accuracy on validation set
# Got 553 / 1000 correct (55.30)
# Training for lr 0.000007, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.1940
# t = 200, loss = 2.1468
# t = 300, loss = 2.1080
# t = 400, loss = 2.0605
# t = 500, loss = 1.9239
# t = 600, loss = 1.9113
# t = 700, loss = 1.9134
# Checking accuracy on validation set
# Got 403 / 1000 correct (40.30)
# Training for lr 0.000007, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.9301
# t = 200, loss = 1.7965
# t = 300, loss = 1.6726
# t = 400, loss = 1.4987
# t = 500, loss = 1.3668
# t = 600, loss = 1.5051
# t = 700, loss = 1.3954
# Checking accuracy on validation set
# Got 551 / 1000 correct (55.10)
# Training for lr 0.000007, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.1932
# t = 200, loss = 2.1103
# t = 300, loss = 2.0269
# t = 400, loss = 1.9303
# t = 500, loss = 1.8550
# t = 600, loss = 1.8392
# t = 700, loss = 1.8792
# Checking accuracy on validation set
# Got 445 / 1000 correct (44.50)
# Training for lr 0.000007, dropouts 0.000939, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.9416
# t = 200, loss = 1.7720
# t = 300, loss = 1.6603
# t = 400, loss = 1.4729
# t = 500, loss = 1.3947
# t = 600, loss = 1.4137
# t = 700, loss = 1.4986
# Checking accuracy on validation set
# Got 545 / 1000 correct (54.50)
# Training for lr 0.000007, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 2.0962
# t = 200, loss = 1.9643
# t = 300, loss = 1.7816
# t = 400, loss = 1.6582
# t = 500, loss = 1.5259
# t = 600, loss = 1.5762
# t = 700, loss = 1.6595
# Checking accuracy on validation set
# Got 489 / 1000 correct (48.90)
# Training for lr 0.000007, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 2.1300
# t = 200, loss = 1.9718
# t = 300, loss = 1.8222
# t = 400, loss = 1.7244
# t = 500, loss = 1.5997
# t = 600, loss = 1.5767
# t = 700, loss = 1.6774
# Checking accuracy on validation set
# Got 481 / 1000 correct (48.10)
# Training for lr 0.000007, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.2611
# t = 200, loss = 2.2202
# t = 300, loss = 2.2212
# t = 400, loss = 2.1882
# t = 500, loss = 2.0979
# t = 600, loss = 2.1120
# t = 700, loss = 2.0378
# Checking accuracy on validation set
# Got 359 / 1000 correct (35.90)
# Training for lr 0.000007, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 2.0666
# t = 200, loss = 1.9328
# t = 300, loss = 1.9157
# t = 400, loss = 1.6628
# t = 500, loss = 1.5633
# t = 600, loss = 1.6129
# t = 700, loss = 1.6544
# Checking accuracy on validation set
# Got 483 / 1000 correct (48.30)
# Training for lr 0.000007, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.2730
# t = 200, loss = 2.2130
# t = 300, loss = 2.1924
# t = 400, loss = 2.1395
# t = 500, loss = 2.0256
# t = 600, loss = 2.0194
# t = 700, loss = 1.9729
# Checking accuracy on validation set
# Got 374 / 1000 correct (37.40)
# Training for lr 0.000007, dropouts 0.206116, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 2.0430
# t = 200, loss = 1.8872
# t = 300, loss = 1.7921
# t = 400, loss = 1.6892
# t = 500, loss = 1.5556
# t = 600, loss = 1.5692
# t = 700, loss = 1.6159
# Checking accuracy on validation set
# Got 472 / 1000 correct (47.20)
# Training for lr 0.000007, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 2.2220
# t = 200, loss = 2.1460
# t = 300, loss = 2.0527
# t = 400, loss = 1.9752
# t = 500, loss = 1.8711
# t = 600, loss = 1.8569
# t = 700, loss = 1.8461
# Checking accuracy on validation set
# Got 174 / 1000 correct (17.40)
# Training for lr 0.000007, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 2.2738
# t = 200, loss = 2.0936
# t = 300, loss = 2.0600
# t = 400, loss = 1.9842
# t = 500, loss = 1.9005
# t = 600, loss = 1.8491
# t = 700, loss = 1.8210
# Checking accuracy on validation set
# Got 176 / 1000 correct (17.60)
# Training for lr 0.000007, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.3102
# t = 200, loss = 2.3020
# t = 300, loss = 2.3340
# t = 400, loss = 2.2909
# t = 500, loss = 2.2294
# t = 600, loss = 2.2785
# t = 700, loss = 2.2335
# Checking accuracy on validation set
# Got 196 / 1000 correct (19.60)
# Training for lr 0.000007, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 2.2701
# t = 200, loss = 2.1862
# t = 300, loss = 2.0719
# t = 400, loss = 1.9827
# t = 500, loss = 1.8766
# t = 600, loss = 1.8326
# t = 700, loss = 1.7994
# Checking accuracy on validation set
# Got 201 / 1000 correct (20.10)
# Training for lr 0.000007, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.3034
# t = 200, loss = 2.2807
# t = 300, loss = 2.2629
# t = 400, loss = 2.2750
# t = 500, loss = 2.2600
# t = 600, loss = 2.2265
# t = 700, loss = 2.2028
# Checking accuracy on validation set
# Got 268 / 1000 correct (26.80)
# Training for lr 0.000007, dropouts 0.457537, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 2.3239
# t = 200, loss = 2.1425
# t = 300, loss = 2.0512
# t = 400, loss = 1.9495
# t = 500, loss = 1.8245
# t = 600, loss = 1.7979
# t = 700, loss = 1.7896
# Checking accuracy on validation set
# Got 471 / 1000 correct (47.10)
# Training for lr 0.000007, dropouts 0.000000, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.8845
# t = 200, loss = 1.7942
# t = 300, loss = 1.6686
# t = 400, loss = 1.4980
# t = 500, loss = 1.2866
# t = 600, loss = 1.4801
# t = 700, loss = 1.4832
# Checking accuracy on validation set
# Got 531 / 1000 correct (53.10)
# Training for lr 0.002619, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.5907
# t = 200, loss = 1.6352
# t = 300, loss = 1.4655
# t = 400, loss = 0.9461
# t = 500, loss = 1.1284
# t = 600, loss = 1.1277
# t = 700, loss = 1.3321
# Checking accuracy on validation set
# Got 544 / 1000 correct (54.40)
# Training for lr 0.002619, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1
# t = 100, loss = 1.7417
# t = 200, loss = 1.5624
# t = 300, loss = 1.4661
# t = 400, loss = 1.4224
# t = 500, loss = 1.3173
# t = 600, loss = 1.3058
# t = 700, loss = 1.5524
# Checking accuracy on validation set
# Got 462 / 1000 correct (46.20)
# Training for lr 0.002619, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 2.366130
# Starting epoch 1 / 1
# t = 100, loss = 2.2377
# t = 200, loss = 2.2096
# t = 300, loss = 2.2254
# t = 400, loss = 2.2866
# t = 500, loss = 2.3028
# t = 600, loss = 2.3026
# t = 700, loss = 2.3020
# Checking accuracy on validation set
# Got 113 / 1000 correct (11.30)
# Training for lr 0.002619, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.003346
# Starting epoch 1 / 1
# t = 100, loss = 1.5874
# t = 200, loss = 1.5302
# t = 300, loss = 1.6200
# t = 400, loss = 1.4644
# t = 500, loss = 1.5043
# t = 600, loss = 1.4635
# t = 700, loss = 1.6441
# Checking accuracy on validation set
# Got 495 / 1000 correct (49.50)
# Training for lr 0.002619, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 1.355523
# Starting epoch 1 / 1
# t = 100, loss = 2.2394
# t = 200, loss = 2.2377
# t = 300, loss = 2.2205
# t = 400, loss = 2.2821
# t = 500, loss = 2.2945
# t = 600, loss = 2.3026
# t = 700, loss = 2.3020
# Checking accuracy on validation set
# Got 87 / 1000 correct (8.70)
# Training for lr 0.002619, dropouts 0.105940, beta1 0.000000, beta2 0.000000, weight_decay 0.000000
# Starting epoch 1 / 1
# t = 100, loss = 1.6084
# t = 200, loss = 1.4939
# t = 300, loss = 1.5439
# t = 400, loss = 1.0067
# t = 500, loss = 1.0880
# t = 600, loss = 1.0806
# t = 700, loss = 1.3391
# Checking accuracy on validation set
# Got 478 / 1000 correct (47.80)
# Training for lr 0.002619, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 0.000012
# Starting epoch 1 / 1
# t = 100, loss = 1.6573
# t = 200, loss = 1.5621
# t = 300, loss = 1.5309
# t = 400, loss = 1.1041
# t = 500, loss = 1.1815
# t = 600, loss = 1.2081
# t = 700, loss = 1.3285
# Checking accuracy on validation set
# Got 556 / 1000 correct (55.60)
# Training for lr 0.002619, dropouts 0.012146, beta1 0.000000, beta2 0.000000, weight_decay 0.002008
# Starting epoch 1 / 1

# %% [markdown]
# ### Describe what you did
#
# In the cell below you should write an explanation of what you did, any additional features that you implemented, and any visualizations or graphs that you make in the process of training and evaluating your network.

# %% [markdown]
# Tell us here!

# %% [markdown]
# ## Test set -- run this only once
#
# Now that we've gotten a result we're happy with, we test our final model on the test set (which you should store in best_model).  This would be the score we would achieve on a competition. Think about how this compares to your validation set accuracy.

# %%
best_model = None
check_accuracy(best_model, loader_test)

# %% [markdown]
# ## Going further with PyTorch
#
# The next assignment will make heavy use of PyTorch. You might also find it useful for your projects.
#
# Here's a nice tutorial by Justin Johnson that shows off some of PyTorch's features, like dynamic graphs and custom NN modules: http://pytorch.org/tutorials/beginner/pytorch_with_examples.html
#
# If you're interested in reinforcement learning for your final project, this is a good (more advanced) DQN tutorial in PyTorch: http://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html
